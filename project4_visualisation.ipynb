# %%
import pandas as pd
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder


data = pd.read_csv("ObesityDataSet.csv")
data
# Out:
#       Gender        Age    Height      Weight family_history_with_overweight  \
# 0     Female  21.000000  1.620000   64.000000                            yes
# 1     Female  21.000000  1.520000   56.000000                            yes
# 2       Male  23.000000  1.800000   77.000000                            yes
# 3       Male  27.000000  1.800000   87.000000                             no
# 4       Male  22.000000  1.780000   89.800000                             no
# ...      ...        ...       ...         ...                            ...
# 2106  Female  20.976842  1.710730  131.408528                            yes
# 2107  Female  21.982942  1.748584  133.742943                            yes
# 2108  Female  22.524036  1.752206  133.689352                            yes
# 2109  Female  24.361936  1.739450  133.346641                            yes
# 2110  Female  23.664709  1.738836  133.472641                            yes
#
#      FAVC  FCVC  NCP       CAEC SMOKE      CH2O  SCC       FAF       TUE  \
# 0      no   2.0  3.0  Sometimes    no  2.000000   no  0.000000  1.000000
# 1      no   3.0  3.0  Sometimes   yes  3.000000  yes  3.000000  0.000000
# 2      no   2.0  3.0  Sometimes    no  2.000000   no  2.000000  1.000000
# 3      no   3.0  3.0  Sometimes    no  2.000000   no  2.000000  0.000000
# 4      no   2.0  1.0  Sometimes    no  2.000000   no  0.000000  0.000000
# ...   ...   ...  ...        ...   ...       ...  ...       ...       ...
# 2106  yes   3.0  3.0  Sometimes    no  1.728139   no  1.676269  0.906247
# 2107  yes   3.0  3.0  Sometimes    no  2.005130   no  1.341390  0.599270
# 2108  yes   3.0  3.0  Sometimes    no  2.054193   no  1.414209  0.646288
# 2109  yes   3.0  3.0  Sometimes    no  2.852339   no  1.139107  0.586035
# 2110  yes   3.0  3.0  Sometimes    no  2.863513   no  1.026452  0.714137
#
#             CALC                 MTRANS           NObeyesdad
# 0             no  Public_Transportation        Normal_Weight
# 1      Sometimes  Public_Transportation        Normal_Weight
# 2     Frequently  Public_Transportation        Normal_Weight
# 3     Frequently                Walking   Overweight_Level_I
# 4      Sometimes  Public_Transportation  Overweight_Level_II
# ...          ...                    ...                  ...
# 2106   Sometimes  Public_Transportation     Obesity_Type_III
# 2107   Sometimes  Public_Transportation     Obesity_Type_III
# 2108   Sometimes  Public_Transportation     Obesity_Type_III
# 2109   Sometimes  Public_Transportation     Obesity_Type_III
# 2110   Sometimes  Public_Transportation     Obesity_Type_III
#
# [2111 rows x 17 columns]

# %%
# Display basic information about the dataset
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2111 entries, 0 to 2110
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Gender                          2111 non-null   object
#  1   Age                             2111 non-null   float64
#  2   Height                          2111 non-null   float64
#  3   Weight                          2111 non-null   float64
#  4   family_history_with_overweight  2111 non-null   object
#  5   FAVC                            2111 non-null   object
#  6   FCVC                            2111 non-null   float64
#  7   NCP                             2111 non-null   float64
#  8   CAEC                            2111 non-null   object
#  9   SMOKE                           2111 non-null   object
#  10  CH2O                            2111 non-null   float64
#  11  SCC                             2111 non-null   object
#  12  FAF                             2111 non-null   float64
#  13  TUE                             2111 non-null   float64
#  14  CALC                            2111 non-null   object
#  15  MTRANS                          2111 non-null   object
#  16  NObeyesdad                      2111 non-null   object
# dtypes: float64(8), object(9)
# memory usage: 280.5+ KB
# None

# %%
# Display basic statistics of the dataset
print("\nBasic statistics of the dataset:")
data.describe()
# Out:
# Basic statistics of the dataset:
#                Age       Height       Weight         FCVC          NCP  \
# count  2111.000000  2111.000000  2111.000000  2111.000000  2111.000000
# mean     24.312600     1.701677    86.586058     2.419043     2.685628
# std       6.345968     0.093305    26.191172     0.533927     0.778039
# min      14.000000     1.450000    39.000000     1.000000     1.000000
# 25%      19.947192     1.630000    65.473343     2.000000     2.658738
# 50%      22.777890     1.700499    83.000000     2.385502     3.000000
# 75%      26.000000     1.768464   107.430682     3.000000     3.000000
# max      61.000000     1.980000   173.000000     3.000000     4.000000
#
#               CH2O          FAF          TUE
# count  2111.000000  2111.000000  2111.000000
# mean      2.008011     1.010298     0.657866
# std       0.612953     0.850592     0.608927
# min       1.000000     0.000000     0.000000
# 25%       1.584812     0.124505     0.000000
# 50%       2.000000     1.000000     0.625350
# 75%       2.477420     1.666678     1.000000
# max       3.000000     3.000000     2.000000

# %%
# Display the column names
print("\nColumn names:")
data.columns
# Out:
# Column names:
# Index(['Gender', 'Age', 'Height', 'Weight', 'family_history_with_overweight',
#        'FAVC', 'FCVC', 'NCP', 'CAEC', 'SMOKE', 'CH2O', 'SCC', 'FAF', 'TUE',
#        'CALC', 'MTRANS', 'NObeyesdad'],
#       dtype='object')

# %%
#Check for and handle missing values
print("\nChecking for missing values:")
print(data.isnull().sum())
# Out:
# Checking for missing values:
# Gender                            0
# Age                               0
# Height                            0
# Weight                            0
# family_history_with_overweight    0
# FAVC                              0
# FCVC                              0
# NCP                               0
# CAEC                              0
# SMOKE                             0
# CH2O                              0
# SCC                               0
# FAF                               0
# TUE                               0
# CALC                              0
# MTRANS                            0
# NObeyesdad                        0
# dtype: int64

# %%
#Check for and handle duplicate entries
print("\nChecking for duplicate entries:")
print(data.duplicated().sum())
# Out:
# Checking for duplicate entries:
# 24

# %%
data = data.drop_duplicates()
print(data.duplicated().sum())
# Out:
# 0

# %%
# Display cleaned data information
print("\nCleaned dataset information:")
print(data.info())
# Out:
# Cleaned dataset information:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2087 entries, 0 to 2110
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Gender                          2087 non-null   object
#  1   Age                             2087 non-null   float64
#  2   Height                          2087 non-null   float64
#  3   Weight                          2087 non-null   float64
#  4   family_history_with_overweight  2087 non-null   object
#  5   FAVC                            2087 non-null   object
#  6   FCVC                            2087 non-null   float64
#  7   NCP                             2087 non-null   float64
#  8   CAEC                            2087 non-null   object
#  9   SMOKE                           2087 non-null   object
#  10  CH2O                            2087 non-null   float64
#  11  SCC                             2087 non-null   object
#  12  FAF                             2087 non-null   float64
#  13  TUE                             2087 non-null   float64
#  14  CALC                            2087 non-null   object
#  15  MTRANS                          2087 non-null   object
#  16  NObeyesdad                      2087 non-null   object
# dtypes: float64(8), object(9)
# memory usage: 293.5+ KB
# None

# %%
# Save cleaned data to a new CSV file
data.to_csv("Cleaned_ObesityDataSet.csv", index=False)
print("\nCleaned dataset saved to 'Cleaned_ObesityDataSet.csv'")
# Out:
# Cleaned dataset saved to 'Cleaned_ObesityDataSet.csv'

# %%
# Load the cleaned dataset
cleaned_data = pd.read_csv("Cleaned_ObesityDataSet.csv")

# %%
# Get a summary of the data
cleaned_data.describe()
# Out:
#                Age       Height       Weight         FCVC          NCP  \
# count  2087.000000  2087.000000  2087.000000  2087.000000  2087.000000
# mean     24.353090     1.702674    86.858730     2.421466     2.701179
# std       6.368801     0.093186    26.190847     0.534737     0.764614
# min      14.000000     1.450000    39.000000     1.000000     1.000000
# 25%      19.915937     1.630178    66.000000     2.000000     2.697467
# 50%      22.847618     1.701584    83.101100     2.396265     3.000000
# 75%      26.000000     1.769491   108.015907     3.000000     3.000000
# max      61.000000     1.980000   173.000000     3.000000     4.000000
#
#               CH2O          FAF          TUE  FAF_Category
# count  2087.000000  2087.000000  2087.000000   2012.000000
# mean      2.004749     1.012812     0.663035      1.190855
# std       0.608284     0.853475     0.608153      1.191031
# min       1.000000     0.000000     0.000000      0.000000
# 25%       1.590922     0.124505     0.000000      0.000000
# 50%       2.000000     1.000000     0.630866      1.000000
# 75%       2.466193     1.678102     1.000000      2.000000
# max       3.000000     3.000000     2.000000      4.000000

# %%
gender_column = 'Gender'   

# Display the distribution of gender
gender_distribution = cleaned_data[gender_column].value_counts()
print("\nDistribution of gender:")
print(gender_distribution)

# Plot the distribution of gender
gender_distribution.plot(kind='bar')
plt.title('Gender Distribution')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()
# Out:
# Distribution of gender:
# Gender
# Male      1052
# Female    1035
# Name: count, dtype: int64

# %%
 
age_column = 'Age'  # Replace with the actual column name if different

# Display summary statistics of the age column
print("\nSummary statistics of age:")
print(cleaned_data[age_column].describe())

# Plot the distribution of age
plt.figure(figsize=(15, 6))
plt.hist(cleaned_data[age_column], bins=20, edgecolor='black')
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()
# Out:
# Summary statistics of age:
# count    2087.000000
# mean       24.353090
# std         6.368801
# min        14.000000
# 25%        19.915937
# 50%        22.847618
# 75%        26.000000
# max        61.000000
# Name: Age, dtype: float64

# %%
 

height_column = 'Height'  
weight_column = 'Weight'  

# Display summary statistics of the height and weight columns
print("\nSummary statistics of height:")
print(cleaned_data[height_column].describe())

print("\nSummary statistics of weight:")
print(cleaned_data[weight_column].describe())

# Plot the distribution of height
plt.figure(figsize=(17, 6))
plt.subplot(1, 2, 1)
plt.hist(cleaned_data[height_column], bins=20, edgecolor='black')
plt.title('Height Distribution')
plt.xlabel('Height')
plt.ylabel('Frequency')

# Plot the distribution of weight
plt.subplot(1, 2, 2)
plt.hist(cleaned_data[weight_column], bins=20, edgecolor='black')
plt.title('Weight Distribution')
plt.xlabel('Weight')
plt.ylabel('Frequency')

# Show the plots
plt.tight_layout()
plt.show()
# Out:
# Summary statistics of height:
# count    2087.000000
# mean        1.702674
# std         0.093186
# min         1.450000
# 25%         1.630178
# 50%         1.701584
# 75%         1.769491
# max         1.980000
# Name: Height, dtype: float64
#
# Summary statistics of weight:
# count    2087.000000
# mean       86.858730
# std        26.190847
# min        39.000000
# 25%        66.000000
# 50%        83.101100
# 75%       108.015907
# max       173.000000
# Name: Weight, dtype: float64

# %%
family_history_column = 'family_history_with_overweight'  

# Display the distribution of family history with overweight
family_history_distribution = cleaned_data[family_history_column].value_counts()
print("\nDistribution of family history with overweight:")
print(family_history_distribution)

# Plot the distribution of family history with overweight
plt.figure(figsize=(8, 6))
family_history_distribution.plot(kind='bar', color=['skyblue', 'lightcoral'])
plt.title('Family History with Overweight Distribution')
plt.xlabel('Family History with Overweight')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.show()
# Out:
# Distribution of family history with overweight:
# family_history_with_overweight
# yes    1722
# no      365
# Name: count, dtype: int64

# %%
obesity_type_column = 'NObeyesdad'   

# Calculate the frequency of each type of obesity
obesity_type_distribution = cleaned_data[obesity_type_column].value_counts()

# Plot a bar chart to visualize the distribution
plt.figure(figsize=(10, 6))
obesity_type_distribution.plot(kind='bar', color='skyblue')
plt.title('Distribution of Obesity Types')
plt.xlabel('Obesity Type')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')   
plt.tight_layout()
plt.show()

# %%
gender_column = 'Gender'  # Replace with the actual column name if different
weight_column = 'Weight'  # Replace with the actual column name if different

# Group the data by gender and calculate the average weight within each group
average_weight_by_gender = cleaned_data.groupby(gender_column)[weight_column].mean()

# Plot a pie chart to visualize the distribution of average weight by gender
plt.figure(figsize=(8, 8))
plt.pie(average_weight_by_gender, labels=average_weight_by_gender.index, autopct='%1.1f%%', colors=['pink', 'skyblue'])
plt.title('Distribution of Average Weight by Gender')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle
plt.show()

# %%
# Read the CSV file into a DataFrame
df = pd.read_csv('Cleaned_ObesityDataSet.csv')

# Convert categorical columns to numeric using Label Encoding
label_encoder = LabelEncoder()

df['Gender'] = label_encoder.fit_transform(df['Gender'])
df['MTRANS'] = label_encoder.fit_transform(df['MTRANS'])
df['FAVC'] = label_encoder.fit_transform(df['FAVC'])
df['family_history_with_overweight'] = label_encoder.fit_transform(df['family_history_with_overweight'])
df['NObeyesdad'] = label_encoder.fit_transform(df['NObeyesdad'])
df['CALC'] = label_encoder.fit_transform(df['CALC'])
df['CAEC'] = label_encoder.fit_transform(df['CAEC'])
df['SMOKE'] = label_encoder.fit_transform(df['SMOKE'])
df['SCC'] = label_encoder.fit_transform(df['SCC'])

# Calculate the correlation matrix
correlation_matrix = df.corr()

# Plot the heatmap
plt.figure(figsize=(18, 12))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Heatmap for Obesity Dataset')
plt.show()

# %%
def interpret_correlation(correlation_matrix):
    for column in correlation_matrix.columns:
        for index in correlation_matrix.index:
            if column != index:
                correlation = correlation_matrix.loc[index, column]
                if correlation > 0.7:
                    strength = "strong"
                    direction = "positive"
                elif correlation > 0.3:
                    strength = "moderate"
                    direction = "positive"
                elif correlation > 0:
                    strength = "weak"
                    direction = "positive"
                elif correlation < -0.7:
                    strength = "strong"
                    direction = "negative"
                elif correlation < -0.3:
                    strength = "moderate"
                    direction = "negative"
                elif correlation < 0:
                    strength = "weak"
                    direction = "negative"
                else:
                    strength = "no"
                    direction = "linear relationship"

                print(f"The correlation between {index} and {column} is {correlation:.2f}, indicating a {strength} {direction} relationship.")

# Interpret the correlation matrix
interpret_correlation(correlation_matrix)

# Interpret the correlation matrix
interpretations = interpret_correlation(correlation_matrix)
# Out:
# The correlation between Age and Gender is 0.05, indicating a weak positive relationship.
# The correlation between Height and Gender is 0.63, indicating a moderate positive relationship.
# The correlation between Weight and Gender is 0.16, indicating a weak positive relationship.
# The correlation between family_history_with_overweight and Gender is 0.11, indicating a weak positive relationship.
# The correlation between FAVC and Gender is 0.06, indicating a weak positive relationship.
# The correlation between FCVC and Gender is -0.27, indicating a weak negative relationship.
# The correlation between NCP and Gender is 0.08, indicating a weak positive relationship.
# The correlation between CAEC and Gender is 0.07, indicating a weak positive relationship.
# The correlation between SMOKE and Gender is 0.05, indicating a weak positive relationship.
# The correlation between CH2O and Gender is 0.10, indicating a weak positive relationship.
# The correlation between SCC and Gender is -0.10, indicating a weak negative relationship.
# The correlation between FAF and Gender is 0.19, indicating a weak positive relationship.
# The correlation between TUE and Gender is 0.02, indicating a weak positive relationship.
# The correlation between CALC and Gender is 0.01, indicating a weak positive relationship.
# The correlation between MTRANS and Gender is -0.14, indicating a weak negative relationship.
# The correlation between NObeyesdad and Gender is 0.01, indicating a weak positive relationship.
# The correlation between Gender and Age is 0.05, indicating a weak positive relationship.
# The correlation between Height and Age is -0.03, indicating a weak negative relationship.
# The correlation between Weight and Age is 0.20, indicating a weak positive relationship.
# The correlation between family_history_with_overweight and Age is 0.20, indicating a weak positive relationship.
# The correlation between FAVC and Age is 0.06, indicating a weak positive relationship.
# The correlation between FCVC and Age is 0.01, indicating a weak positive relationship.
# The correlation between NCP and Age is -0.06, indicating a weak negative relationship.
# The correlation between CAEC and Age is 0.09, indicating a weak positive relationship.
# The correlation between SMOKE and Age is 0.09, indicating a weak positive relationship.
# The correlation between CH2O and Age is -0.04, indicating a weak negative relationship.
# The correlation between SCC and Age is -0.12, indicating a weak negative relationship.
# The correlation between FAF and Age is -0.15, indicating a weak negative relationship.
# The correlation between TUE and Age is -0.30, indicating a moderate negative relationship.
# The correlation between CALC and Age is -0.05, indicating a weak negative relationship.
# The correlation between MTRANS and Age is -0.60, indicating a moderate negative relationship.
# The correlation between NObeyesdad and Age is 0.24, indicating a weak positive relationship.
# The correlation between Gender and Height is 0.63, indicating a moderate positive relationship.
# The correlation between Age and Height is -0.03, indicating a weak negative relationship.
# The correlation between Weight and Height is 0.46, indicating a moderate positive relationship.
# The correlation between family_history_with_overweight and Height is 0.23, indicating a weak positive relationship.
# The correlation between FAVC and Height is 0.18, indicating a weak positive relationship.
# The correlation between FCVC and Height is -0.04, indicating a weak negative relationship.
# The correlation between NCP and Height is 0.23, indicating a weak positive relationship.
# The correlation between CAEC and Height is 0.06, indicating a weak positive relationship.
# The correlation between SMOKE and Height is 0.05, indicating a weak positive relationship.
# The correlation between CH2O and Height is 0.22, indicating a weak positive relationship.
# The correlation between SCC and Height is -0.14, indicating a weak negative relationship.
# The correlation between FAF and Height is 0.29, indicating a weak positive relationship.
# The correlation between TUE and Height is 0.04, indicating a weak positive relationship.
# The correlation between CALC and Height is -0.14, indicating a weak negative relationship.
# The correlation between MTRANS and Height is -0.07, indicating a weak negative relationship.
# The correlation between NObeyesdad and Height is 0.04, indicating a weak positive relationship.
# The correlation between Gender and Weight is 0.16, indicating a weak positive relationship.
# The correlation between Age and Weight is 0.20, indicating a weak positive relationship.
# The correlation between Height and Weight is 0.46, indicating a moderate positive relationship.
# The correlation between family_history_with_overweight and Weight is 0.49, indicating a moderate positive relationship.
# The correlation between FAVC and Weight is 0.27, indicating a weak positive relationship.
# The correlation between FCVC and Weight is 0.22, indicating a weak positive relationship.
# The correlation between NCP and Weight is 0.09, indicating a weak positive relationship.
# The correlation between CAEC and Weight is 0.30, indicating a moderate positive relationship.
# The correlation between SMOKE and Weight is 0.02, indicating a weak positive relationship.
# The correlation between CH2O and Weight is 0.20, indicating a weak positive relationship.
# The correlation between SCC and Weight is -0.21, indicating a weak negative relationship.
# The correlation between FAF and Weight is -0.06, indicating a weak negative relationship.
# The correlation between TUE and Weight is -0.08, indicating a weak negative relationship.
# The correlation between CALC and Weight is -0.21, indicating a weak negative relationship.
# The correlation between MTRANS and Weight is 0.01, indicating a weak positive relationship.
# The correlation between NObeyesdad and Weight is 0.39, indicating a moderate positive relationship.
# The correlation between Gender and family_history_with_overweight is 0.11, indicating a weak positive relationship.
# The correlation between Age and family_history_with_overweight is 0.20, indicating a weak positive relationship.
# The correlation between Height and family_history_with_overweight is 0.23, indicating a weak positive relationship.
# The correlation between Weight and family_history_with_overweight is 0.49, indicating a moderate positive relationship.
# The correlation between FAVC and family_history_with_overweight is 0.21, indicating a weak positive relationship.
# The correlation between FCVC and family_history_with_overweight is 0.03, indicating a weak positive relationship.
# The correlation between NCP and family_history_with_overweight is 0.03, indicating a weak positive relationship.
# The correlation between CAEC and family_history_with_overweight is 0.21, indicating a weak positive relationship.
# The correlation between SMOKE and family_history_with_overweight is 0.01, indicating a weak positive relationship.
# The correlation between CH2O and family_history_with_overweight is 0.17, indicating a weak positive relationship.
# The correlation between SCC and family_history_with_overweight is -0.19, indicating a weak negative relationship.
# The correlation between FAF and family_history_with_overweight is -0.06, indicating a weak negative relationship.
# The correlation between TUE and family_history_with_overweight is 0.00, indicating a weak positive relationship.
# The correlation between CALC and family_history_with_overweight is 0.03, indicating a weak positive relationship.
# The correlation between MTRANS and family_history_with_overweight is -0.09, indicating a weak negative relationship.
# The correlation between NObeyesdad and family_history_with_overweight is 0.33, indicating a moderate positive relationship.
# The correlation between Gender and FAVC is 0.06, indicating a weak positive relationship.
# The correlation between Age and FAVC is 0.06, indicating a weak positive relationship.
# The correlation between Height and FAVC is 0.18, indicating a weak positive relationship.
# The correlation between Weight and FAVC is 0.27, indicating a weak positive relationship.
# The correlation between family_history_with_overweight and FAVC is 0.21, indicating a weak positive relationship.
# The correlation between FCVC and FAVC is -0.03, indicating a weak negative relationship.
# The correlation between NCP and FAVC is -0.01, indicating a weak negative relationship.
# The correlation between CAEC and FAVC is 0.15, indicating a weak positive relationship.
# The correlation between SMOKE and FAVC is -0.05, indicating a weak negative relationship.
# The correlation between CH2O and FAVC is 0.00, indicating a weak positive relationship.
# The correlation between SCC and FAVC is -0.19, indicating a weak negative relationship.
# The correlation between FAF and FAVC is -0.11, indicating a weak negative relationship.
# The correlation between TUE and FAVC is 0.07, indicating a weak positive relationship.
# The correlation between CALC and FAVC is -0.09, indicating a weak negative relationship.
# The correlation between MTRANS and FAVC is -0.07, indicating a weak negative relationship.
# The correlation between NObeyesdad and FAVC is 0.04, indicating a weak positive relationship.
# The correlation between Gender and FCVC is -0.27, indicating a weak negative relationship.
# The correlation between Age and FCVC is 0.01, indicating a weak positive relationship.
# The correlation between Height and FCVC is -0.04, indicating a weak negative relationship.
# The correlation between Weight and FCVC is 0.22, indicating a weak positive relationship.
# The correlation between family_history_with_overweight and FCVC is 0.03, indicating a weak positive relationship.
# The correlation between FAVC and FCVC is -0.03, indicating a weak negative relationship.
# The correlation between NCP and FCVC is 0.03, indicating a weak positive relationship.
# The correlation between CAEC and FCVC is -0.04, indicating a weak negative relationship.
# The correlation between SMOKE and FCVC is 0.01, indicating a weak positive relationship.
# The correlation between CH2O and FCVC is 0.08, indicating a weak positive relationship.
# The correlation between SCC and FCVC is 0.07, indicating a weak positive relationship.
# The correlation between FAF and FCVC is 0.02, indicating a weak positive relationship.
# The correlation between TUE and FCVC is -0.10, indicating a weak negative relationship.
# The correlation between CALC and FCVC is -0.06, indicating a weak negative relationship.
# The correlation between MTRANS and FCVC is 0.07, indicating a weak positive relationship.
# The correlation between NObeyesdad and FCVC is 0.03, indicating a weak positive relationship.
# The correlation between Gender and NCP is 0.08, indicating a weak positive relationship.
# The correlation between Age and NCP is -0.06, indicating a weak negative relationship.
# The correlation between Height and NCP is 0.23, indicating a weak positive relationship.
# The correlation between Weight and NCP is 0.09, indicating a weak positive relationship.
# The correlation between family_history_with_overweight and NCP is 0.03, indicating a weak positive relationship.
# The correlation between FAVC and NCP is -0.01, indicating a weak negative relationship.
# The correlation between FCVC and NCP is 0.03, indicating a weak positive relationship.
# The correlation between CAEC and NCP is -0.07, indicating a weak negative relationship.
# The correlation between SMOKE and NCP is 0.01, indicating a weak positive relationship.
# The correlation between CH2O and NCP is 0.08, indicating a weak positive relationship.
# The correlation between SCC and NCP is -0.02, indicating a weak negative relationship.
# The correlation between FAF and NCP is 0.13, indicating a weak positive relationship.
# The correlation between TUE and NCP is 0.02, indicating a weak positive relationship.
# The correlation between CALC and NCP is -0.08, indicating a weak negative relationship.
# The correlation between MTRANS and NCP is -0.04, indicating a weak negative relationship.
# The correlation between NObeyesdad and NCP is -0.09, indicating a weak negative relationship.
# The correlation between Gender and CAEC is 0.07, indicating a weak positive relationship.
# The correlation between Age and CAEC is 0.09, indicating a weak positive relationship.
# The correlation between Height and CAEC is 0.06, indicating a weak positive relationship.
# The correlation between Weight and CAEC is 0.30, indicating a moderate positive relationship.
# The correlation between family_history_with_overweight and CAEC is 0.21, indicating a weak positive relationship.
# The correlation between FAVC and CAEC is 0.15, indicating a weak positive relationship.
# The correlation between FCVC and CAEC is -0.04, indicating a weak negative relationship.
# The correlation between NCP and CAEC is -0.07, indicating a weak negative relationship.
# The correlation between SMOKE and CAEC is -0.05, indicating a weak negative relationship.
# The correlation between CH2O and CAEC is 0.11, indicating a weak positive relationship.
# The correlation between SCC and CAEC is -0.11, indicating a weak negative relationship.
# The correlation between FAF and CAEC is -0.03, indicating a weak negative relationship.
# The correlation between TUE and CAEC is -0.04, indicating a weak negative relationship.
# The correlation between CALC and CAEC is -0.04, indicating a weak negative relationship.
# The correlation between MTRANS and CAEC is -0.06, indicating a weak negative relationship.
# The correlation between NObeyesdad and CAEC is 0.31, indicating a moderate positive relationship.
# The correlation between Gender and SMOKE is 0.05, indicating a weak positive relationship.
# The correlation between Age and SMOKE is 0.09, indicating a weak positive relationship.
# The correlation between Height and SMOKE is 0.05, indicating a weak positive relationship.
# The correlation between Weight and SMOKE is 0.02, indicating a weak positive relationship.
# The correlation between family_history_with_overweight and SMOKE is 0.01, indicating a weak positive relationship.
# The correlation between FAVC and SMOKE is -0.05, indicating a weak negative relationship.
# The correlation between FCVC and SMOKE is 0.01, indicating a weak positive relationship.
# The correlation between NCP and SMOKE is 0.01, indicating a weak positive relationship.
# The correlation between CAEC and SMOKE is -0.05, indicating a weak negative relationship.
# The correlation between CH2O and SMOKE is -0.03, indicating a weak negative relationship.
# The correlation between SCC and SMOKE is 0.05, indicating a weak positive relationship.
# The correlation between FAF and SMOKE is 0.01, indicating a weak positive relationship.
# The correlation between TUE and SMOKE is 0.02, indicating a weak positive relationship.
# The correlation between CALC and SMOKE is -0.08, indicating a weak negative relationship.
# The correlation between MTRANS and SMOKE is -0.01, indicating a weak negative relationship.
# The correlation between NObeyesdad and SMOKE is -0.02, indicating a weak negative relationship.
# The correlation between Gender and CH2O is 0.10, indicating a weak positive relationship.
# The correlation between Age and CH2O is -0.04, indicating a weak negative relationship.
# The correlation between Height and CH2O is 0.22, indicating a weak positive relationship.
# The correlation between Weight and CH2O is 0.20, indicating a weak positive relationship.
# The correlation between family_history_with_overweight and CH2O is 0.17, indicating a weak positive relationship.
# The correlation between FAVC and CH2O is 0.00, indicating a weak positive relationship.
# The correlation between FCVC and CH2O is 0.08, indicating a weak positive relationship.
# The correlation between NCP and CH2O is 0.08, indicating a weak positive relationship.
# The correlation between CAEC and CH2O is 0.11, indicating a weak positive relationship.
# The correlation between SMOKE and CH2O is -0.03, indicating a weak negative relationship.
# The correlation between SCC and CH2O is 0.01, indicating a weak positive relationship.
# The correlation between FAF and CH2O is 0.17, indicating a weak positive relationship.
# The correlation between TUE and CH2O is 0.02, indicating a weak positive relationship.
# The correlation between CALC and CH2O is -0.09, indicating a weak negative relationship.
# The correlation between MTRANS and CH2O is 0.04, indicating a weak positive relationship.
# The correlation between NObeyesdad and CH2O is 0.09, indicating a weak positive relationship.
# The correlation between Gender and SCC is -0.10, indicating a weak negative relationship.
# The correlation between Age and SCC is -0.12, indicating a weak negative relationship.
# The correlation between Height and SCC is -0.14, indicating a weak negative relationship.
# The correlation between Weight and SCC is -0.21, indicating a weak negative relationship.
# The correlation between family_history_with_overweight and SCC is -0.19, indicating a weak negative relationship.
# The correlation between FAVC and SCC is -0.19, indicating a weak negative relationship.
# The correlation between FCVC and SCC is 0.07, indicating a weak positive relationship.
# The correlation between NCP and SCC is -0.02, indicating a weak negative relationship.
# The correlation between CAEC and SCC is -0.11, indicating a weak negative relationship.
# The correlation between SMOKE and SCC is 0.05, indicating a weak positive relationship.
# The correlation between CH2O and SCC is 0.01, indicating a weak positive relationship.
# The correlation between FAF and SCC is 0.07, indicating a weak positive relationship.
# The correlation between TUE and SCC is -0.01, indicating a weak negative relationship.
# The correlation between CALC and SCC is -0.00, indicating a weak negative relationship.
# The correlation between MTRANS and SCC is 0.04, indicating a weak positive relationship.
# The correlation between NObeyesdad and SCC is -0.05, indicating a weak negative relationship.
# The correlation between Gender and FAF is 0.19, indicating a weak positive relationship.
# The correlation between Age and FAF is -0.15, indicating a weak negative relationship.
# The correlation between Height and FAF is 0.29, indicating a weak positive relationship.
# The correlation between Weight and FAF is -0.06, indicating a weak negative relationship.
# The correlation between family_history_with_overweight and FAF is -0.06, indicating a weak negative relationship.
# The correlation between FAVC and FAF is -0.11, indicating a weak negative relationship.
# The correlation between FCVC and FAF is 0.02, indicating a weak positive relationship.
# The correlation between NCP and FAF is 0.13, indicating a weak positive relationship.
# The correlation between CAEC and FAF is -0.03, indicating a weak negative relationship.
# The correlation between SMOKE and FAF is 0.01, indicating a weak positive relationship.
# The correlation between CH2O and FAF is 0.17, indicating a weak positive relationship.
# The correlation between SCC and FAF is 0.07, indicating a weak positive relationship.
# The correlation between TUE and FAF is 0.06, indicating a weak positive relationship.
# The correlation between CALC and FAF is 0.09, indicating a weak positive relationship.
# The correlation between MTRANS and FAF is 0.01, indicating a weak positive relationship.
# The correlation between NObeyesdad and FAF is -0.14, indicating a weak negative relationship.
# The correlation between Gender and TUE is 0.02, indicating a weak positive relationship.
# The correlation between Age and TUE is -0.30, indicating a moderate negative relationship.
# The correlation between Height and TUE is 0.04, indicating a weak positive relationship.
# The correlation between Weight and TUE is -0.08, indicating a weak negative relationship.
# The correlation between family_history_with_overweight and TUE is 0.00, indicating a weak positive relationship.
# The correlation between FAVC and TUE is 0.07, indicating a weak positive relationship.
# The correlation between FCVC and TUE is -0.10, indicating a weak negative relationship.
# The correlation between NCP and TUE is 0.02, indicating a weak positive relationship.
# The correlation between CAEC and TUE is -0.04, indicating a weak negative relationship.
# The correlation between SMOKE and TUE is 0.02, indicating a weak positive relationship.
# The correlation between CH2O and TUE is 0.02, indicating a weak positive relationship.
# The correlation between SCC and TUE is -0.01, indicating a weak negative relationship.
# The correlation between FAF and TUE is 0.06, indicating a weak positive relationship.
# The correlation between CALC and TUE is 0.04, indicating a weak positive relationship.
# The correlation between MTRANS and TUE is 0.18, indicating a weak positive relationship.
# The correlation between NObeyesdad and TUE is -0.06, indicating a weak negative relationship.
# The correlation between Gender and CALC is 0.01, indicating a weak positive relationship.
# The correlation between Age and CALC is -0.05, indicating a weak negative relationship.
# The correlation between Height and CALC is -0.14, indicating a weak negative relationship.
# The correlation between Weight and CALC is -0.21, indicating a weak negative relationship.
# The correlation between family_history_with_overweight and CALC is 0.03, indicating a weak positive relationship.
# The correlation between FAVC and CALC is -0.09, indicating a weak negative relationship.
# The correlation between FCVC and CALC is -0.06, indicating a weak negative relationship.
# The correlation between NCP and CALC is -0.08, indicating a weak negative relationship.
# The correlation between CAEC and CALC is -0.04, indicating a weak negative relationship.
# The correlation between SMOKE and CALC is -0.08, indicating a weak negative relationship.
# The correlation between CH2O and CALC is -0.09, indicating a weak negative relationship.
# The correlation between SCC and CALC is -0.00, indicating a weak negative relationship.
# The correlation between FAF and CALC is 0.09, indicating a weak positive relationship.
# The correlation between TUE and CALC is 0.04, indicating a weak positive relationship.
# The correlation between MTRANS and CALC is -0.01, indicating a weak negative relationship.
# The correlation between NObeyesdad and CALC is -0.13, indicating a weak negative relationship.
# The correlation between Gender and MTRANS is -0.14, indicating a weak negative relationship.
# The correlation between Age and MTRANS is -0.60, indicating a moderate negative relationship.
# The correlation between Height and MTRANS is -0.07, indicating a weak negative relationship.
# The correlation between Weight and MTRANS is 0.01, indicating a weak positive relationship.
# The correlation between family_history_with_overweight and MTRANS is -0.09, indicating a weak negative relationship.
# The correlation between FAVC and MTRANS is -0.07, indicating a weak negative relationship.
# The correlation between FCVC and MTRANS is 0.07, indicating a weak positive relationship.
# The correlation between NCP and MTRANS is -0.04, indicating a weak negative relationship.
# The correlation between CAEC and MTRANS is -0.06, indicating a weak negative relationship.
# The correlation between SMOKE and MTRANS is -0.01, indicating a weak negative relationship.
# The correlation between CH2O and MTRANS is 0.04, indicating a weak positive relationship.
# The correlation between SCC and MTRANS is 0.04, indicating a weak positive relationship.
# The correlation between FAF and MTRANS is 0.01, indicating a weak positive relationship.
# The correlation between TUE and MTRANS is 0.18, indicating a weak positive relationship.
# The correlation between CALC and MTRANS is -0.01, indicating a weak negative relationship.
# The correlation between NObeyesdad and MTRANS is -0.05, indicating a weak negative relationship.
# The correlation between Gender and NObeyesdad is 0.01, indicating a weak positive relationship.
# The correlation between Age and NObeyesdad is 0.24, indicating a weak positive relationship.
# The correlation between Height and NObeyesdad is 0.04, indicating a weak positive relationship.
# The correlation between Weight and NObeyesdad is 0.39, indicating a moderate positive relationship.
# The correlation between family_history_with_overweight and NObeyesdad is 0.33, indicating a moderate positive relationship.
# The correlation between FAVC and NObeyesdad is 0.04, indicating a weak positive relationship.
# The correlation between FCVC and NObeyesdad is 0.03, indicating a weak positive relationship.
# The correlation between NCP and NObeyesdad is -0.09, indicating a weak negative relationship.
# The correlation between CAEC and NObeyesdad is 0.31, indicating a moderate positive relationship.
# The correlation between SMOKE and NObeyesdad is -0.02, indicating a weak negative relationship.
# The correlation between CH2O and NObeyesdad is 0.09, indicating a weak positive relationship.
# The correlation between SCC and NObeyesdad is -0.05, indicating a weak negative relationship.
# The correlation between FAF and NObeyesdad is -0.14, indicating a weak negative relationship.
# The correlation between TUE and NObeyesdad is -0.06, indicating a weak negative relationship.
# The correlation between CALC and NObeyesdad is -0.13, indicating a weak negative relationship.
# The correlation between MTRANS and NObeyesdad is -0.05, indicating a weak negative relationship.
# The correlation between Age and Gender is 0.05, indicating a weak positive relationship.
# The correlation between Height and Gender is 0.63, indicating a moderate positive relationship.
# The correlation between Weight and Gender is 0.16, indicating a weak positive relationship.
# The correlation between family_history_with_overweight and Gender is 0.11, indicating a weak positive relationship.
# The correlation between FAVC and Gender is 0.06, indicating a weak positive relationship.
# The correlation between FCVC and Gender is -0.27, indicating a weak negative relationship.
# The correlation between NCP and Gender is 0.08, indicating a weak positive relationship.
# The correlation between CAEC and Gender is 0.07, indicating a weak positive relationship.
# The correlation between SMOKE and Gender is 0.05, indicating a weak positive relationship.
# The correlation between CH2O and Gender is 0.10, indicating a weak positive relationship.
# The correlation between SCC and Gender is -0.10, indicating a weak negative relationship.
# The correlation between FAF and Gender is 0.19, indicating a weak positive relationship.
# The correlation between TUE and Gender is 0.02, indicating a weak positive relationship.
# The correlation between CALC and Gender is 0.01, indicating a weak positive relationship.
# The correlation between MTRANS and Gender is -0.14, indicating a weak negative relationship.
# The correlation between NObeyesdad and Gender is 0.01, indicating a weak positive relationship.
# The correlation between Gender and Age is 0.05, indicating a weak positive relationship.
# The correlation between Height and Age is -0.03, indicating a weak negative relationship.
# The correlation between Weight and Age is 0.20, indicating a weak positive relationship.
# The correlation between family_history_with_overweight and Age is 0.20, indicating a weak positive relationship.
# The correlation between FAVC and Age is 0.06, indicating a weak positive relationship.
# The correlation between FCVC and Age is 0.01, indicating a weak positive relationship.
# The correlation between NCP and Age is -0.06, indicating a weak negative relationship.
# The correlation between CAEC and Age is 0.09, indicating a weak positive relationship.
# The correlation between SMOKE and Age is 0.09, indicating a weak positive relationship.
# The correlation between CH2O and Age is -0.04, indicating a weak negative relationship.
# The correlation between SCC and Age is -0.12, indicating a weak negative relationship.
# The correlation between FAF and Age is -0.15, indicating a weak negative relationship.
# The correlation between TUE and Age is -0.30, indicating a moderate negative relationship.
# The correlation between CALC and Age is -0.05, indicating a weak negative relationship.
# The correlation between MTRANS and Age is -0.60, indicating a moderate negative relationship.
# The correlation between NObeyesdad and Age is 0.24, indicating a weak positive relationship.
# The correlation between Gender and Height is 0.63, indicating a moderate positive relationship.
# The correlation between Age and Height is -0.03, indicating a weak negative relationship.
# The correlation between Weight and Height is 0.46, indicating a moderate positive relationship.
# The correlation between family_history_with_overweight and Height is 0.23, indicating a weak positive relationship.
# The correlation between FAVC and Height is 0.18, indicating a weak positive relationship.
# The correlation between FCVC and Height is -0.04, indicating a weak negative relationship.
# The correlation between NCP and Height is 0.23, indicating a weak positive relationship.
# The correlation between CAEC and Height is 0.06, indicating a weak positive relationship.
# The correlation between SMOKE and Height is 0.05, indicating a weak positive relationship.
# The correlation between CH2O and Height is 0.22, indicating a weak positive relationship.
# The correlation between SCC and Height is -0.14, indicating a weak negative relationship.
# The correlation between FAF and Height is 0.29, indicating a weak positive relationship.
# The correlation between TUE and Height is 0.04, indicating a weak positive relationship.
# The correlation between CALC and Height is -0.14, indicating a weak negative relationship.
# The correlation between MTRANS and Height is -0.07, indicating a weak negative relationship.
# The correlation between NObeyesdad and Height is 0.04, indicating a weak positive relationship.
# The correlation between Gender and Weight is 0.16, indicating a weak positive relationship.
# The correlation between Age and Weight is 0.20, indicating a weak positive relationship.
# The correlation between Height and Weight is 0.46, indicating a moderate positive relationship.
# The correlation between family_history_with_overweight and Weight is 0.49, indicating a moderate positive relationship.
# The correlation between FAVC and Weight is 0.27, indicating a weak positive relationship.
# The correlation between FCVC and Weight is 0.22, indicating a weak positive relationship.
# The correlation between NCP and Weight is 0.09, indicating a weak positive relationship.
# The correlation between CAEC and Weight is 0.30, indicating a moderate positive relationship.
# The correlation between SMOKE and Weight is 0.02, indicating a weak positive relationship.
# The correlation between CH2O and Weight is 0.20, indicating a weak positive relationship.
# The correlation between SCC and Weight is -0.21, indicating a weak negative relationship.
# The correlation between FAF and Weight is -0.06, indicating a weak negative relationship.
# The correlation between TUE and Weight is -0.08, indicating a weak negative relationship.
# The correlation between CALC and Weight is -0.21, indicating a weak negative relationship.
# The correlation between MTRANS and Weight is 0.01, indicating a weak positive relationship.
# The correlation between NObeyesdad and Weight is 0.39, indicating a moderate positive relationship.
# The correlation between Gender and family_history_with_overweight is 0.11, indicating a weak positive relationship.
# The correlation between Age and family_history_with_overweight is 0.20, indicating a weak positive relationship.
# The correlation between Height and family_history_with_overweight is 0.23, indicating a weak positive relationship.
# The correlation between Weight and family_history_with_overweight is 0.49, indicating a moderate positive relationship.
# The correlation between FAVC and family_history_with_overweight is 0.21, indicating a weak positive relationship.
# The correlation between FCVC and family_history_with_overweight is 0.03, indicating a weak positive relationship.
# The correlation between NCP and family_history_with_overweight is 0.03, indicating a weak positive relationship.
# The correlation between CAEC and family_history_with_overweight is 0.21, indicating a weak positive relationship.
# The correlation between SMOKE and family_history_with_overweight is 0.01, indicating a weak positive relationship.
# The correlation between CH2O and family_history_with_overweight is 0.17, indicating a weak positive relationship.
# The correlation between SCC and family_history_with_overweight is -0.19, indicating a weak negative relationship.
# The correlation between FAF and family_history_with_overweight is -0.06, indicating a weak negative relationship.
# The correlation between TUE and family_history_with_overweight is 0.00, indicating a weak positive relationship.
# The correlation between CALC and family_history_with_overweight is 0.03, indicating a weak positive relationship.
# The correlation between MTRANS and family_history_with_overweight is -0.09, indicating a weak negative relationship.
# The correlation between NObeyesdad and family_history_with_overweight is 0.33, indicating a moderate positive relationship.
# The correlation between Gender and FAVC is 0.06, indicating a weak positive relationship.
# The correlation between Age and FAVC is 0.06, indicating a weak positive relationship.
# The correlation between Height and FAVC is 0.18, indicating a weak positive relationship.
# The correlation between Weight and FAVC is 0.27, indicating a weak positive relationship.
# The correlation between family_history_with_overweight and FAVC is 0.21, indicating a weak positive relationship.
# The correlation between FCVC and FAVC is -0.03, indicating a weak negative relationship.
# The correlation between NCP and FAVC is -0.01, indicating a weak negative relationship.
# The correlation between CAEC and FAVC is 0.15, indicating a weak positive relationship.
# The correlation between SMOKE and FAVC is -0.05, indicating a weak negative relationship.
# The correlation between CH2O and FAVC is 0.00, indicating a weak positive relationship.
# The correlation between SCC and FAVC is -0.19, indicating a weak negative relationship.
# The correlation between FAF and FAVC is -0.11, indicating a weak negative relationship.
# The correlation between TUE and FAVC is 0.07, indicating a weak positive relationship.
# The correlation between CALC and FAVC is -0.09, indicating a weak negative relationship.
# The correlation between MTRANS and FAVC is -0.07, indicating a weak negative relationship.
# The correlation between NObeyesdad and FAVC is 0.04, indicating a weak positive relationship.
# The correlation between Gender and FCVC is -0.27, indicating a weak negative relationship.
# The correlation between Age and FCVC is 0.01, indicating a weak positive relationship.
# The correlation between Height and FCVC is -0.04, indicating a weak negative relationship.
# The correlation between Weight and FCVC is 0.22, indicating a weak positive relationship.
# The correlation between family_history_with_overweight and FCVC is 0.03, indicating a weak positive relationship.
# The correlation between FAVC and FCVC is -0.03, indicating a weak negative relationship.
# The correlation between NCP and FCVC is 0.03, indicating a weak positive relationship.
# The correlation between CAEC and FCVC is -0.04, indicating a weak negative relationship.
# The correlation between SMOKE and FCVC is 0.01, indicating a weak positive relationship.
# The correlation between CH2O and FCVC is 0.08, indicating a weak positive relationship.
# The correlation between SCC and FCVC is 0.07, indicating a weak positive relationship.
# The correlation between FAF and FCVC is 0.02, indicating a weak positive relationship.
# The correlation between TUE and FCVC is -0.10, indicating a weak negative relationship.
# The correlation between CALC and FCVC is -0.06, indicating a weak negative relationship.
# The correlation between MTRANS and FCVC is 0.07, indicating a weak positive relationship.
# The correlation between NObeyesdad and FCVC is 0.03, indicating a weak positive relationship.
# The correlation between Gender and NCP is 0.08, indicating a weak positive relationship.
# The correlation between Age and NCP is -0.06, indicating a weak negative relationship.
# The correlation between Height and NCP is 0.23, indicating a weak positive relationship.
# The correlation between Weight and NCP is 0.09, indicating a weak positive relationship.
# The correlation between family_history_with_overweight and NCP is 0.03, indicating a weak positive relationship.
# The correlation between FAVC and NCP is -0.01, indicating a weak negative relationship.
# The correlation between FCVC and NCP is 0.03, indicating a weak positive relationship.
# The correlation between CAEC and NCP is -0.07, indicating a weak negative relationship.
# The correlation between SMOKE and NCP is 0.01, indicating a weak positive relationship.
# The correlation between CH2O and NCP is 0.08, indicating a weak positive relationship.
# The correlation between SCC and NCP is -0.02, indicating a weak negative relationship.
# The correlation between FAF and NCP is 0.13, indicating a weak positive relationship.
# The correlation between TUE and NCP is 0.02, indicating a weak positive relationship.
# The correlation between CALC and NCP is -0.08, indicating a weak negative relationship.
# The correlation between MTRANS and NCP is -0.04, indicating a weak negative relationship.
# The correlation between NObeyesdad and NCP is -0.09, indicating a weak negative relationship.
# The correlation between Gender and CAEC is 0.07, indicating a weak positive relationship.
# The correlation between Age and CAEC is 0.09, indicating a weak positive relationship.
# The correlation between Height and CAEC is 0.06, indicating a weak positive relationship.
# The correlation between Weight and CAEC is 0.30, indicating a moderate positive relationship.
# The correlation between family_history_with_overweight and CAEC is 0.21, indicating a weak positive relationship.
# The correlation between FAVC and CAEC is 0.15, indicating a weak positive relationship.
# The correlation between FCVC and CAEC is -0.04, indicating a weak negative relationship.
# The correlation between NCP and CAEC is -0.07, indicating a weak negative relationship.
# The correlation between SMOKE and CAEC is -0.05, indicating a weak negative relationship.
# The correlation between CH2O and CAEC is 0.11, indicating a weak positive relationship.
# The correlation between SCC and CAEC is -0.11, indicating a weak negative relationship.
# The correlation between FAF and CAEC is -0.03, indicating a weak negative relationship.
# The correlation between TUE and CAEC is -0.04, indicating a weak negative relationship.
# The correlation between CALC and CAEC is -0.04, indicating a weak negative relationship.
# The correlation between MTRANS and CAEC is -0.06, indicating a weak negative relationship.
# The correlation between NObeyesdad and CAEC is 0.31, indicating a moderate positive relationship.
# The correlation between Gender and SMOKE is 0.05, indicating a weak positive relationship.
# The correlation between Age and SMOKE is 0.09, indicating a weak positive relationship.
# The correlation between Height and SMOKE is 0.05, indicating a weak positive relationship.
# The correlation between Weight and SMOKE is 0.02, indicating a weak positive relationship.
# The correlation between family_history_with_overweight and SMOKE is 0.01, indicating a weak positive relationship.
# The correlation between FAVC and SMOKE is -0.05, indicating a weak negative relationship.
# The correlation between FCVC and SMOKE is 0.01, indicating a weak positive relationship.
# The correlation between NCP and SMOKE is 0.01, indicating a weak positive relationship.
# The correlation between CAEC and SMOKE is -0.05, indicating a weak negative relationship.
# The correlation between CH2O and SMOKE is -0.03, indicating a weak negative relationship.
# The correlation between SCC and SMOKE is 0.05, indicating a weak positive relationship.
# The correlation between FAF and SMOKE is 0.01, indicating a weak positive relationship.
# The correlation between TUE and SMOKE is 0.02, indicating a weak positive relationship.
# The correlation between CALC and SMOKE is -0.08, indicating a weak negative relationship.
# The correlation between MTRANS and SMOKE is -0.01, indicating a weak negative relationship.
# The correlation between NObeyesdad and SMOKE is -0.02, indicating a weak negative relationship.
# The correlation between Gender and CH2O is 0.10, indicating a weak positive relationship.
# The correlation between Age and CH2O is -0.04, indicating a weak negative relationship.
# The correlation between Height and CH2O is 0.22, indicating a weak positive relationship.
# The correlation between Weight and CH2O is 0.20, indicating a weak positive relationship.
# The correlation between family_history_with_overweight and CH2O is 0.17, indicating a weak positive relationship.
# The correlation between FAVC and CH2O is 0.00, indicating a weak positive relationship.
# The correlation between FCVC and CH2O is 0.08, indicating a weak positive relationship.
# The correlation between NCP and CH2O is 0.08, indicating a weak positive relationship.
# The correlation between CAEC and CH2O is 0.11, indicating a weak positive relationship.
# The correlation between SMOKE and CH2O is -0.03, indicating a weak negative relationship.
# The correlation between SCC and CH2O is 0.01, indicating a weak positive relationship.
# The correlation between FAF and CH2O is 0.17, indicating a weak positive relationship.
# The correlation between TUE and CH2O is 0.02, indicating a weak positive relationship.
# The correlation between CALC and CH2O is -0.09, indicating a weak negative relationship.
# The correlation between MTRANS and CH2O is 0.04, indicating a weak positive relationship.
# The correlation between NObeyesdad and CH2O is 0.09, indicating a weak positive relationship.
# The correlation between Gender and SCC is -0.10, indicating a weak negative relationship.
# The correlation between Age and SCC is -0.12, indicating a weak negative relationship.
# The correlation between Height and SCC is -0.14, indicating a weak negative relationship.
# The correlation between Weight and SCC is -0.21, indicating a weak negative relationship.
# The correlation between family_history_with_overweight and SCC is -0.19, indicating a weak negative relationship.
# The correlation between FAVC and SCC is -0.19, indicating a weak negative relationship.
# The correlation between FCVC and SCC is 0.07, indicating a weak positive relationship.
# The correlation between NCP and SCC is -0.02, indicating a weak negative relationship.
# The correlation between CAEC and SCC is -0.11, indicating a weak negative relationship.
# The correlation between SMOKE and SCC is 0.05, indicating a weak positive relationship.
# The correlation between CH2O and SCC is 0.01, indicating a weak positive relationship.
# The correlation between FAF and SCC is 0.07, indicating a weak positive relationship.
# The correlation between TUE and SCC is -0.01, indicating a weak negative relationship.
# The correlation between CALC and SCC is -0.00, indicating a weak negative relationship.
# The correlation between MTRANS and SCC is 0.04, indicating a weak positive relationship.
# The correlation between NObeyesdad and SCC is -0.05, indicating a weak negative relationship.
# The correlation between Gender and FAF is 0.19, indicating a weak positive relationship.
# The correlation between Age and FAF is -0.15, indicating a weak negative relationship.
# The correlation between Height and FAF is 0.29, indicating a weak positive relationship.
# The correlation between Weight and FAF is -0.06, indicating a weak negative relationship.
# The correlation between family_history_with_overweight and FAF is -0.06, indicating a weak negative relationship.
# The correlation between FAVC and FAF is -0.11, indicating a weak negative relationship.
# The correlation between FCVC and FAF is 0.02, indicating a weak positive relationship.
# The correlation between NCP and FAF is 0.13, indicating a weak positive relationship.
# The correlation between CAEC and FAF is -0.03, indicating a weak negative relationship.
# The correlation between SMOKE and FAF is 0.01, indicating a weak positive relationship.
# The correlation between CH2O and FAF is 0.17, indicating a weak positive relationship.
# The correlation between SCC and FAF is 0.07, indicating a weak positive relationship.
# The correlation between TUE and FAF is 0.06, indicating a weak positive relationship.
# The correlation between CALC and FAF is 0.09, indicating a weak positive relationship.
# The correlation between MTRANS and FAF is 0.01, indicating a weak positive relationship.
# The correlation between NObeyesdad and FAF is -0.14, indicating a weak negative relationship.
# The correlation between Gender and TUE is 0.02, indicating a weak positive relationship.
# The correlation between Age and TUE is -0.30, indicating a moderate negative relationship.
# The correlation between Height and TUE is 0.04, indicating a weak positive relationship.
# The correlation between Weight and TUE is -0.08, indicating a weak negative relationship.
# The correlation between family_history_with_overweight and TUE is 0.00, indicating a weak positive relationship.
# The correlation between FAVC and TUE is 0.07, indicating a weak positive relationship.
# The correlation between FCVC and TUE is -0.10, indicating a weak negative relationship.
# The correlation between NCP and TUE is 0.02, indicating a weak positive relationship.
# The correlation between CAEC and TUE is -0.04, indicating a weak negative relationship.
# The correlation between SMOKE and TUE is 0.02, indicating a weak positive relationship.
# The correlation between CH2O and TUE is 0.02, indicating a weak positive relationship.
# The correlation between SCC and TUE is -0.01, indicating a weak negative relationship.
# The correlation between FAF and TUE is 0.06, indicating a weak positive relationship.
# The correlation between CALC and TUE is 0.04, indicating a weak positive relationship.
# The correlation between MTRANS and TUE is 0.18, indicating a weak positive relationship.
# The correlation between NObeyesdad and TUE is -0.06, indicating a weak negative relationship.
# The correlation between Gender and CALC is 0.01, indicating a weak positive relationship.
# The correlation between Age and CALC is -0.05, indicating a weak negative relationship.
# The correlation between Height and CALC is -0.14, indicating a weak negative relationship.
# The correlation between Weight and CALC is -0.21, indicating a weak negative relationship.
# The correlation between family_history_with_overweight and CALC is 0.03, indicating a weak positive relationship.
# The correlation between FAVC and CALC is -0.09, indicating a weak negative relationship.
# The correlation between FCVC and CALC is -0.06, indicating a weak negative relationship.
# The correlation between NCP and CALC is -0.08, indicating a weak negative relationship.
# The correlation between CAEC and CALC is -0.04, indicating a weak negative relationship.
# The correlation between SMOKE and CALC is -0.08, indicating a weak negative relationship.
# The correlation between CH2O and CALC is -0.09, indicating a weak negative relationship.
# The correlation between SCC and CALC is -0.00, indicating a weak negative relationship.
# The correlation between FAF and CALC is 0.09, indicating a weak positive relationship.
# The correlation between TUE and CALC is 0.04, indicating a weak positive relationship.
# The correlation between MTRANS and CALC is -0.01, indicating a weak negative relationship.
# The correlation between NObeyesdad and CALC is -0.13, indicating a weak negative relationship.
# The correlation between Gender and MTRANS is -0.14, indicating a weak negative relationship.
# The correlation between Age and MTRANS is -0.60, indicating a moderate negative relationship.
# The correlation between Height and MTRANS is -0.07, indicating a weak negative relationship.
# The correlation between Weight and MTRANS is 0.01, indicating a weak positive relationship.
# The correlation between family_history_with_overweight and MTRANS is -0.09, indicating a weak negative relationship.
# The correlation between FAVC and MTRANS is -0.07, indicating a weak negative relationship.
# The correlation between FCVC and MTRANS is 0.07, indicating a weak positive relationship.
# The correlation between NCP and MTRANS is -0.04, indicating a weak negative relationship.
# The correlation between CAEC and MTRANS is -0.06, indicating a weak negative relationship.
# The correlation between SMOKE and MTRANS is -0.01, indicating a weak negative relationship.
# The correlation between CH2O and MTRANS is 0.04, indicating a weak positive relationship.
# The correlation between SCC and MTRANS is 0.04, indicating a weak positive relationship.
# The correlation between FAF and MTRANS is 0.01, indicating a weak positive relationship.
# The correlation between TUE and MTRANS is 0.18, indicating a weak positive relationship.
# The correlation between CALC and MTRANS is -0.01, indicating a weak negative relationship.
# The correlation between NObeyesdad and MTRANS is -0.05, indicating a weak negative relationship.
# The correlation between Gender and NObeyesdad is 0.01, indicating a weak positive relationship.
# The correlation between Age and NObeyesdad is 0.24, indicating a weak positive relationship.
# The correlation between Height and NObeyesdad is 0.04, indicating a weak positive relationship.
# The correlation between Weight and NObeyesdad is 0.39, indicating a moderate positive relationship.
# The correlation between family_history_with_overweight and NObeyesdad is 0.33, indicating a moderate positive relationship.
# The correlation between FAVC and NObeyesdad is 0.04, indicating a weak positive relationship.
# The correlation between FCVC and NObeyesdad is 0.03, indicating a weak positive relationship.
# The correlation between NCP and NObeyesdad is -0.09, indicating a weak negative relationship.
# The correlation between CAEC and NObeyesdad is 0.31, indicating a moderate positive relationship.
# The correlation between SMOKE and NObeyesdad is -0.02, indicating a weak negative relationship.
# The correlation between CH2O and NObeyesdad is 0.09, indicating a weak positive relationship.
# The correlation between SCC and NObeyesdad is -0.05, indicating a weak negative relationship.
# The correlation between FAF and NObeyesdad is -0.14, indicating a weak negative relationship.
# The correlation between TUE and NObeyesdad is -0.06, indicating a weak negative relationship.
# The correlation between CALC and NObeyesdad is -0.13, indicating a weak negative relationship.
# The correlation between MTRANS and NObeyesdad is -0.05, indicating a weak negative relationship.

# %%
# Necessary imports
import pandas as pd
import matplotlib.pyplot as plt

# Define the file path
file_path = 'Cleaned_ObesityDataSet.csv'

# Read the CSV file into a DataFrame
cleaned_data = pd.read_csv(file_path)

# Define gender and obesity columns
gender_column = 'Gender'
obesity_column = 'NObeyesdad'  

# Ensure the columns exist
if gender_column in cleaned_data.columns and obesity_column in cleaned_data.columns:
    # Display summary statistics of the gender and obesity columns
    print("\nSummary statistics of gender:")
    print(cleaned_data[gender_column].describe())

    print("\nSummary statistics of obesity (NObeyesdad):")
    print(cleaned_data[obesity_column].describe())
    
    # Create a crosstab to count obesity status by gender
    gender_obesity_counts = pd.crosstab(cleaned_data[gender_column], cleaned_data[obesity_column])
    
    # Define colors for each obesity status category
    unique_obesity_categories = cleaned_data[obesity_column].unique()
    colors = ['skyblue', 'salmon', 'lightgreen', 'gold', 'lightpink', 'lightcoral', 'mediumpurple'][:len(unique_obesity_categories)]
    
    # Plot the data
    ax = gender_obesity_counts.plot(kind='bar', stacked=True, color=colors, figsize=(18, 8))
    plt.title('Obesity Status by Gender')
    plt.xlabel('Gender')
    plt.ylabel('Count')
    plt.xticks(rotation=0)  # Keep x-axis labels horizontal
    plt.legend(title='Obesity Status (NObeyesdad)', bbox_to_anchor=(1.05, 1), loc='upper left')  # Place legend outside the plot
    plt.tight_layout()
    plt.show()
else:
    print(f"One or both columns '{gender_column}' and '{obesity_column}' do not exist in the DataFrame.")
# Out:
# Summary statistics of gender:
# count     2087
# unique       2
# top       Male
# freq      1052
# Name: Gender, dtype: object
#
# Summary statistics of obesity (NObeyesdad):
# count               2087
# unique                 7
# top       Obesity_Type_I
# freq                 351
# Name: NObeyesdad, dtype: object

# %%
# Define columns
obesity_column = 'NObeyesdad'  # Assuming 'NObeyesdad' is the column indicating obesity status
gender_column = 'Gender'  # Assuming 'Gender' is the column indicating gender

# Ensure the columns exist
if obesity_column in cleaned_data.columns and gender_column in cleaned_data.columns:
    # Create a crosstab to count obesity status by gender
    crosstab = pd.crosstab(cleaned_data[obesity_column], cleaned_data[gender_column])

    # Plot the graph
    crosstab.plot(kind='bar', figsize=(18, 8))
    plt.title('Distribution of NObeyesdad by Gender')
    plt.xlabel('NObeyesdad Level')
    plt.ylabel('Count')
    plt.xticks(rotation=0)  # Rotate x-axis labels for better readability
    plt.legend(title='Gender', bbox_to_anchor=(1.05, 1), loc='upper left')  # Place legend outside the plot
    plt.tight_layout()
    plt.show()
else:
    print(f"One or both columns '{obesity_column}' and '{gender_column}' do not exist in the DataFrame.")

# %%
# Define columns
weight_column = 'Weight'
family_history_column = 'family_history_with_overweight'  # Assuming this is the correct column name

# Ensure the columns exist
if weight_column in cleaned_data.columns and family_history_column in cleaned_data.columns:
    # Plot the box plot
    plt.figure(figsize=(12, 12))
    cleaned_data.boxplot(column=weight_column, by=family_history_column)
    plt.title('Weight Distribution by Family History with Overweight')
    plt.xlabel('Family History with Overweight')
    plt.ylabel('Weight')
    plt.suptitle('')  # Remove automatically generated title
    plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
    plt.show()
else:
    print(f"One or both columns '{weight_column}' and '{family_history_column}' do not exist in the DataFrame.")

# %%
# Define columns
obesity_column = 'NObeyesdad'
family_history_column = 'family_history_with_overweight'  # Assuming this is the correct column name

# Ensure the columns exist
if obesity_column in cleaned_data.columns and family_history_column in cleaned_data.columns:
    # Create a crosstab to count obesity status by family history
    crosstab = pd.crosstab(cleaned_data[obesity_column], cleaned_data[family_history_column])

    # Plot the graph
    crosstab.plot(kind='bar', figsize=(10, 6))
    plt.title('Comparison of NObeyesdad and Family History with Overweight')
    plt.xlabel('NObeyesdad')
    plt.ylabel('Count')
    plt.xticks(rotation=0)  # Rotate x-axis labels for better readability
    plt.legend(title='Family History with Overweight', bbox_to_anchor=(1.05, 1), loc='upper left')  # Place legend outside the plot
    plt.tight_layout()
    plt.show()
else:
    print(f"One or both columns '{obesity_column}' and '{family_history_column}' do not exist in the DataFrame.")

# %%
# Define columns
caec_column = 'CAEC'  # Consumption of food between meals
obesity_column = 'NObeyesdad'

# Ensure the columns exist
if caec_column in cleaned_data.columns and obesity_column in cleaned_data.columns:
    # Create a crosstab to count obesity status by CAEC
    crosstab = pd.crosstab(cleaned_data[obesity_column], cleaned_data[caec_column])

    # Plot the graph
    crosstab.plot(kind='bar', figsize=(10, 6))
    plt.title('Comparison of CAEC and NObeyesdad')
    plt.xlabel('CAEC')
    plt.ylabel('Count')
    plt.xticks(rotation=0)  # Rotate x-axis labels for better readability
    plt.legend(title='NObeyesdad', bbox_to_anchor=(1.05, 1), loc='upper left')  # Place legend outside the plot
    plt.tight_layout()
    plt.show()
else:
    print(f"One or both columns '{caec_column}' and '{obesity_column}' do not exist in the DataFrame.")
